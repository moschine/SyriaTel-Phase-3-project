# %% [markdown]
# # Customer Churn Prediction for SyriaTel

# %% [markdown]
# ## introduction

# %% [markdown]
# Telecommunications companies face an ongoing challenge in retaining their customer base amidst a competitive market landscape. For SyriaTel, customer churn has emerged as a pressing issue, with subscribers terminating their subscriptions or migrating to rival service providers. This not only results in revenue loss but also escalates acquisition costs for new customers. In response, the objective of this project is to develop a robust binary classification model capable of accurately predicting customer churn within SyriaTel's user base. By anticipating potential churners in advance, SyriaTel can strategically implement retention tactics and personalized incentives to deter customer attrition.
#
# This endeavor involves leveraging historical customer data encompassing demographic particulars, service usage trends, billing histories, customer tenure, and interactions such as complaints and service requests. The focal point lies in addressing several key challenges: ensuring data quality, conducting comprehensive feature engineering, selecting and optimizing suitable classification algorithms, interpreting model predictions for actionable insights, and upholding ethical considerations surrounding bias mitigation and data privacy.
#
# Successful deployment of the churn prediction model holds immense potential for SyriaTel, offering the ability to preemptively identify at-risk customers and deploy targeted retention measures. By mitigating churn and cultivating customer loyalty, SyriaTel can not only curtail attrition-related costs but also enhance overall customer satisfaction and bolster long-term profitability.

# %% [markdown]
# # Problem statement

# %% [markdown]
# SyriaTel, a telecommunications company, is facing challenges in retaining its customer base. Customer churn, which refers to customers terminating their subscriptions or switching to other service providers, has become a significant issue. This problem not only results in revenue loss but also increases acquisition costs for new customers.
#
# The objective of this project is to develop a binary classification model that can accurately predict whether a customer is likely to churn (stop doing business with SyriaTel) in the near future. By identifying potential churners in advance, SyriaTel can proactively implement targeted retention strategies and personalized offers to prevent customer attrition.
#
# The model will be trained on historical customer data, which includes information such as demographic details, service usage patterns, billing records, customer tenure, and customer interactions (e.g., complaints, service requests). The target variable will be a binary indicator representing whether a customer has churned or not.
#
# ### The key challenges in this project include:
#
# **Data Quality :** Ensuring the availability and quality of relevant customer data, handling missing values, and dealing with potential data inconsistencies or outliers.
#
# **Feature Engineering:** Identifying and engineering informative features from the available data that can effectively capture patterns and characteristics associated with customer churn.
#
# **Model Selection and Optimization:** Choosing an appropriate binary classification algorithm and optimizing its hyperparameters to achieve high predictive performance.
#
# **Interpretability and Actionability:** Interpreting the model's predictions and feature importances to gain insights into the factors contributing to customer churn, enabling the development of effective retention strategies.
#
# **Ethical Considerations:** Ensuring that the model does not exhibit biases or discriminate against customers based on protected characteristics, and addressing potential privacy concerns related to customer data.
#
# The successful development and deployment of this customer churn prediction model will enable SyriaTel to proactively identify customers at risk of churning and implement targeted retention efforts, ultimately reducing customer attrition and associated costs, while improving customer satisfaction and loyalty.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# The dataset contains a comprehensive set of features pertaining to telecommunications services, providing insights into customer behavior and usage patterns. The key demographic information such as state, account length, area code, and phone number are included, allowing for segmentation and analysis based on geographic and temporal factors. Binary variables such as international plan and voice mail plan offer insights into customer preferences and service subscriptions. Additionally, numerical variables like number of voicemail messages, total day minutes, and total day calls provide quantitative measures of customer engagement and usage intensity during different times of the day. Moreover, the dataset encompasses information on charges incurred by customers for various types of calls, including daytime, evening, night, and international calls, enabling detailed analysis of revenue generation and cost management within the telecommunications provider's framework.
#
# Furthermore, the dataset includes indicators of customer interactions and service satisfaction, such as the number of customer service calls made by each customer. This metric can serve as a proxy for customer experience and satisfaction levels, aiding in customer retention efforts and service quality improvements. Lastly, the churn variable stands out as a critical feature, indicating whether a customer has discontinued their service. This binary indicator offers valuable insights into customer attrition rates and retention challenges, facilitating predictive modeling and proactive strategies to mitigate churn and enhance customer loyalty. Overall, this dataset provides a rich source of information for telecom companies to better understand their customer base, optimize service offerings, and improve overall business performance.

# %% [markdown]
# ## Business understanding

# %% [markdown]
# SyriaTel, a telecommunications company, is grappling with customer churn, where subscribers terminate their services or switch to competitors. This issue leads to revenue loss and increased acquisition costs for new customers. To tackle this challenge, SyriaTel aims to develop a robust predictive model capable of accurately identifying customers likely to churn in the near future. The available comprehensive dataset, encompassing customer demographics, service details, usage patterns, billing records, and interaction data, will serve as the foundation for building this churn prediction model. Successful implementation will enable SyriaTel to proactively implement targeted retention strategies, personalized incentives, and tailored offers, thereby mitigating customer attrition, retaining existing revenue streams, reducing acquisition costs, and ultimately enhancing profitability and long-term sustainability. However, ethical considerations such as mitigating biases and protecting customer privacy must be addressed during model development and deployment.

# %%
#importing libraries

# Data manipulation 
import pandas as pd 
import numpy as np 
# Data visualization
import seaborn as sns 
import matplotlib.pyplot as plt 
# Modeling
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV 
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score,confusion_matrix,roc_curve,roc_auc_score,classification_report # performance metrics
from sklearn.preprocessing import MinMaxScaler # to scale the numeric features
from scipy import stats
# Algorithms for supervised learning methods
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Filtering future warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset
df = pd.read_csv(r"C:\Users\PC\Downloads\archive\bigml_59c28831336c6604c800002a.csv")
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
# checking for the dimensions of the DataFrame
df.shape
# Out:
# (3333, 21)

# %%
 #checking for the summary info of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
#generating a descriptive statistics for numerical columns in the DataFrame.
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# # Data preparation and cleaning

# %% [markdown]
# ### defining variables
#
# ##### Categorical Columns:
#     area code
#     state
#     international plan
#     voice mail plan
#
# ##### Numerical Columns:
#
#     account length
#     number vmail messages
#     total day minutes
#     total day calls
#     total day charge
#     total eve minutes
#     total eve calls
#     total eve charge
#     total night minutes
#     total night calls
#     total night charge
#     total intl minutes
#     total intl calls
#     total intl charge
#     customer service calls

# %%
#checking for missing values
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
# Checking for duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
# display the columns
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
# Creating numeric & categorical lists
numerical_cols = ['account length','number vmail messages','total day minutes','total day calls','total day charge',
                'total eve minutes','total eve calls','total eve charge','total night minutes','total night calls',
                'total night charge','total intl minutes','total intl calls','total intl charge','customer service calls']
categorical_cols = ['state','area code','international plan','voice mail plan']

# %%
# Removing customer number feature it's contact information on the client and adds no value to the analysis
df.drop(['phone number'],axis=1,inplace=True)
df.head()
# Out:
#   state  account length  area code international plan voice mail plan  \
# 0    KS             128        415                 no             yes
# 1    OH             107        415                 no             yes
# 2    NJ             137        415                 no              no
# 3    OH              84        408                yes              no
# 4    OK              75        415                yes              no
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Checking for the number of unique values in all columns in the dataframe
df.nunique()
# Out:
# state                       51
# account length             212
# area code                    3
# international plan           2
# voice mail plan              2
# number vmail messages       46
# total day minutes         1667
# total day calls            119
# total day charge          1667
# total eve minutes         1611
# total eve calls            123
# total eve charge          1440
# total night minutes       1591
# total night calls          120
# total night charge         933
# total intl minutes         162
# total intl calls            21
# total intl charge          162
# customer service calls      10
# churn                        2
# dtype: int64

# %%
# checking the number of values in 'international_plan' columns
df['international plan'].value_counts()
# Out:
# international plan
# no     3010
# yes     323
# Name: count, dtype: int64

# %%
# checking the number of values in 'voice_mail_plan' columns
df['voice mail plan'].value_counts()
# Out:
# voice mail plan
# no     2411
# yes     922
# Name: count, dtype: int64

# %% [markdown]
# #  Exploratory Data Analysis

# %%
# Creating categorical columns
categorical_cols = ['state', 'area code', 'international plan', 'voice mail plan']
# Creating numerical columns
numeric_cols = df.drop(categorical_cols, axis=1)
numeric_cols
# Out:
#       account length  number vmail messages  total day minutes  \
# 0                128                     25              265.1
# 1                107                     26              161.6
# 2                137                      0              243.4
# 3                 84                      0              299.4
# 4                 75                      0              166.7
# ...              ...                    ...                ...
# 3328             192                     36              156.2
# 3329              68                      0              231.1
# 3330              28                      0              180.8
# 3331             184                      0              213.8
# 3332              74                     25              234.4
#
#       total day calls  total day charge  total eve minutes  total eve calls  \
# 0                 110             45.07              197.4               99
# ...

# %% [markdown]
# What is the distribution of subscribers based on the target churn feature and identifying the percentage of loyal subscribers.

# %%
# Displaying value counts of unique features
print(df.churn.value_counts())

# Creating a countplot of the 'churn' features
plt.figure(figsize=(8, 6))  
sns.countplot(x='churn', data=df)
plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Churn Count")
plt.show()
# Out:
# churn
# False    2850
# True      483
# Name: count, dtype: int64

# %% [markdown]
# from the graph, about 14.5% of the entire dataset,have terminated their contracts with SyriaTel. The remaining 85.5% have not terminated their contracts. This shows that there is an imbalance in the data, whereby the number of customers who have churned is much lower compared to those who continue to use the service.

# %%
df.head()
# Out:
#   state  account length  area code international plan voice mail plan  \
# 0    KS             128        415                 no             yes
# 1    OH             107        415                 no             yes
# 2    NJ             137        415                 no              no
# 3    OH              84        408                yes              no
# 4    OK              75        415                yes              no
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # Area code Analysis

# %%
# Visualizing/ plotting the distribution of 'area code'
plt.figure(figsize=(10, 6))

sns.countplot(x="area code", data=df)
plt.title("Area Code Distribution")
plt.xlabel("Area Codes")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The graph shows the number of customers for three different area codes: 408, 415, and 510. The height of each bar represents how many customers are from that area code. The bar for area code 510 is the tallest, meaning it has the most customers. The bar for 415 is the shortest, meaning it has the smallest number customers.

# %%
# Box-plotting to check the area code that has the highest churn
plt.figure(figsize=(17,5))
sns.boxplot(data=df,x='churn',y='customer service calls',hue='area code');
plt.legend(loc='upper right');

# %% [markdown]
# . There are outliers, in all area codes, amongst the customers who have not terminated their accounts.
#
# . Of the customers who have terminated their account, they more likely have a 415 or a 510 area code.

# %% [markdown]
# ### Which state's residents talk on the phone the most?, The least?. from all the calls ('total day calls', 'total eve calls', 'total night calls').

# %%
df.head()
# Out:
#   state  account length  area code international plan voice mail plan  \
# 0    KS             128        415                 no             yes
# 1    OH             107        415                 no             yes
# 2    NJ             137        415                 no              no
# 3    OH              84        408                yes              no
# 4    OK              75        415                yes              no
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Creating a new column 'all calls' which sums up the total calls across different times of the day
df['all calls'] = df['total day calls'] + df['total eve calls'] + df['total night calls']

# Grouping the DataFrame by 'state', calculating the sum of 'all calls' for each state, and sorting the result
state_calls = df.groupby('state')['all calls'].sum().sort_values()

# Printing state(s) with the minimum amount of calls
print('State(s) with the minimum amount of calls:\n', state_calls[state_calls == state_calls.min()], sep='')

# Printing state(s) with the maximum amount of calls
print('State(s) with the maximum amount of calls:\n', state_calls[state_calls == state_calls.max()], sep='')

# Plotting the distribution of calls across states using a horizontal bar plot
state_calls.plot(kind='barh', figsize=(20, 15))
plt.xlabel('Amount of calls')
plt.ylabel('State')
plt.title('Distribution of Calls Across States')
plt.show()
# Out:
# State(s) with the minimum amount of calls:
# state
# CA    10431
# Name: all calls, dtype: int64
# State(s) with the maximum amount of calls:
# state
# WV    32055
# Name: all calls, dtype: int64

# %% [markdown]
# ## visualizing categorical feature columns

# %%
for i in categorical_cols:
    plt.figure(figsize=(10,4))
    sns.countplot(x=i, hue="churn", data=df,order= df[i].value_counts().iloc[0:15].index)
    plt.xticks(rotation=90)
    plt.legend(loc="upper right")
    plt.show()

# %% [markdown]
# ### visualizing and analyzing Numerical Features using Pairplots (Hue as 'churn')

# %%
# Definining numeric features
numeric_cols = df[["account length",
                   "total day calls",
                   "total eve calls",
                   "total night calls",
                   "total intl calls",
                   "customer service calls",
                   "churn"
                ]]
# Creating pair plots with 'churn' as hue
sns.pairplot(numeric_cols, hue="churn",height=2.5);
plt.suptitle("Pair Plots of Numeric Features with Hue as 'Churn'", y=1.02);
plt.show();

# %% [markdown]
# The distribution plots for most features display a normal distribution, except for "Customer service calls," which exhibits multiple peaks, suggesting varied levels of customer engagement. This divergence is understandable due to the discrete nature of customer service calls, leading to distinct count values in the distribution.

# %% [markdown]
# ### Correlation Heatmap for Numeric Features

# %%
corr_mat = df[numerical_cols].corr()
mask = np.triu(np.ones_like(corr_mat, dtype=bool))
plt.subplots(figsize=(15,12))
sns.heatmap(corr_mat, annot=True, cmap='Blues', square=True,fmt='.0g');
plt.xticks(rotation=90);
plt.yticks(rotation=0);

# %% [markdown]
# . Account length has a moderate positive correlation with total day minutes and charges.
#
# . Total day minutes and charges are positively correlated with each other and with total evening minutes and charges.
#
# . Total night minutes and charges are negatively correlated with most other features, except for international features.
#
# . International minutes and charges are positively correlated with each other and with night features.
#
# . Customer service calls have a weak negative correlation with most other features.

# %%
print("Before dropping numerical outliers, length of the dataframe is: ",len(df))
def drop_numerical_outliers(df, z_thresh=3):
    constrains = df.select_dtypes(include=[np.number]).apply(lambda x: np.abs(stats.zscore(x)) < z_thresh) \
        .all(axis=1)
    df.drop(df.index[~constrains], inplace=True)
    
drop_numerical_outliers(df)
print("After dropping numerical outliers, length of the dataframe is: ",len(df))
# Out:
# Before dropping numerical outliers, length of the dataframe is:  3333
# After dropping numerical outliers, length of the dataframe is:  3167

# %% [markdown]
# # Feature Selection

# %%
# Selecting relevant columns for modeling
columns = ['account length', 'international plan', 'voice mail plan',
                    'number vmail messages', 'total day minutes', 'total day calls',
                    'total day charge', 'total eve minutes', 'total eve calls',
                    'total eve charge', 'total night minutes', 'total night calls',
                    'total night charge', 'total intl minutes', 'total intl calls',
                    'total intl charge', 'customer service calls', 'churn']

# %%
# Re_assign data to include selected columns
data = df[columns]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3167 entries, 0 to 3332
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account length          3167 non-null   int64
#  1   international plan      3167 non-null   object
#  2   voice mail plan         3167 non-null   object
#  3   number vmail messages   3167 non-null   int64
#  4   total day minutes       3167 non-null   float64
#  5   total day calls         3167 non-null   int64
#  6   total day charge        3167 non-null   float64
#  7   total eve minutes       3167 non-null   float64
#  8   total eve calls         3167 non-null   int64
#  9   total eve charge        3167 non-null   float64
#  10  total night minutes     3167 non-null   float64
#  11  total night calls       3167 non-null   int64
#  12  total night charge      3167 non-null   float64
#  13  total intl minutes      3167 non-null   float64
# ...

# %%
# Encode categorical variables
df = pd.get_dummies(data, columns=['international plan', 'voice mail plan', 'churn'], drop_first=True)

# Display the updated dataset
df.head()
# Out:
#    account length  number vmail messages  total day minutes  total day calls  \
# 0             128                     25              265.1              110
# 1             107                     26              161.6              123
# 2             137                      0              243.4              114
# 3              84                      0              299.4               71
# 4              75                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
# ...

# %%
# Convert categorical variables to numeric
df['international plan_True'] = df['international plan_yes'].astype(int)
df['churn_True'] = df['churn_True'].astype(int)
df['voice mail plan_yes'] = df['voice mail plan_yes'].astype(int)

# %%
#inspect the data variables
data.describe()
# Out:
#        account length  number vmail messages  total day minutes  \
# count     3167.000000            3167.000000        3167.000000
# mean       100.864856               7.979476         180.246700
# std         39.485447              13.589293          53.829134
# min          1.000000               0.000000          17.600000
# 25%         74.000000               0.000000         144.000000
# 50%        100.000000               0.000000         179.800000
# 75%        127.000000              19.000000         216.950000
# max        217.000000              49.000000         337.400000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3167.000000       3167.000000        3167.000000      3167.000000
# mean        100.610673         30.642476         201.039754       100.195137
# std          19.719455          9.150925          50.056949        19.585014
# min          42.000000          2.990000          49.200000        42.000000
# ...

# %% [markdown]
# # Checking for outliers

# %%
# Defining the columns to plot
columns_to_plot = ['number vmail messages', 'total day minutes', 'total day calls', 'total day charge',
                   'total eve minutes', 'total eve calls', 'total eve charge', 'total night minutes',
                   'total night charge', 'total intl minutes', 'total intl calls', 'total intl charge',
                   'customer service calls']

# Calculating the number of rows and columns for the subplot grid
num_rows = 4
num_cols = 4

# Creating subplot grid
fig, axs = plt.subplots(num_rows, num_cols, figsize=(17, 10))

# Flattening the axs array for easier indexing
axs = axs.flatten()

# Plotting each column in the subplot grid
for i, column in enumerate(columns_to_plot):
    sns.boxplot(df[column], ax=axs[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## removing outliers using the trimming Method

# %%
to_modify = ['number vmail messages', 'total day minutes', 'total day calls', 'total day charge',
                   'total eve minutes', 'total eve calls', 'total eve charge', 'total night minutes',
                   'total night charge', 'total intl minutes', 'total intl calls', 'total intl charge',
                   'customer service calls']
for col in to_modify:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    data = data[(data[col] >= Q1 - 1.5*IQR) & (data[col] <= Q3 + 1.5*IQR)]

# %%
# Defining the columns to plot
columns_to_plot = ['number vmail messages', 'total day minutes', 'total day calls', 'total day charge',
                   'total eve minutes', 'total eve calls', 'total eve charge', 'total night minutes',
                   'total night charge', 'total intl minutes', 'total intl calls', 'total intl charge',
                   'customer service calls']

# Calculating the number of rows and columns for the subplot grid
num_rows = 4
num_cols = 4

# Creating subplot grid
fig, axs = plt.subplots(num_rows, num_cols, figsize=(17, 10))

# Flattening the axs array for easier indexing
axs = axs.flatten()

# Plotting each column in the subplot grid
for i, column in enumerate(columns_to_plot):
    sns.boxplot(df[column], ax=axs[i])

plt.tight_layout()
plt.show()

# %%
# Checking for 'churn' value counts
churn_value_counts = df['churn_True'].value_counts(normalize=True)

# Plotting histogram to visualize churn distribution
plt.figure(figsize=(8, 6))
plt.bar(churn_value_counts.index, churn_value_counts.values, color=['lightblue', 'lightcoral'])
plt.xlabel('Churn')
plt.ylabel('Percentage')
plt.title('Churn Distribution')
plt.xticks(churn_value_counts.index, ['Non-Churned', 'Churned'])
plt.show()

# %% [markdown]
# The visualization reveals that the majority of customers, accounting for 86.1%, are classified as non-churned, while only 13.9% are labeled as churned. This disparity highlights a class imbalance issue in the dataset. Such an imbalance could skew predictions and result in insufficient consideration of the churn class during the modeling process. In simpler terms, there are far more instances of non-churned customers compared to churned customers, which may impact the accuracy of our predictions and the effectiveness of our models in identifying customers likely to churn.

# %% [markdown]
# ## splitting the data

# %%
df['churn_True'].value_counts()
# Out:
# churn_True
# 0    2726
# 1     441
# Name: count, dtype: int64

# %%
# create dummy variables for categorical columns
df = pd.get_dummies(df)

# %%
#creating a target and futures variable
#target
y = df.churn_True
# features columns
x = df.drop('churn_True', axis = 1)

# %%
#training the df
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# # Data Modelling and Evaluation

# %% [markdown]
# #### Model 1: DecisionTreeClassifier

# %%
# instantiate decision tree classifier
model = DecisionTreeClassifier(max_depth = 5)

model.fit(x_train, y_train)
predict = model.predict(x_test)
accuracy = accuracy_score(predict, y_test)
print(accuracy)

# calculate recall_score for test df:
print(precision_score(y_test, model.predict(x_test)))

# calculate recall_score for test df:
print(recall_score(y_test, model.predict(x_test)))
# Out:
# 0.9381313131313131
# 0.891566265060241
# 0.6491228070175439

# %% [markdown]
# The accuracy score tells us the proportion of correctly classified instances out of the total instances. In this case, the accuracy is approximately 0.937, meaning that around 93.7% of the instances in the test set were correctly classified by the DecisionTreeClassifier model.
#
# Precision measures the proportion of true positive predictions (correctly predicted positives) out of all positive predictions made by the model. Here, the precision score is approximately 0.890, indicating that around 89.0% of the predicted positive cases were correct.
#
# Recall (also known as sensitivity or true positive rate) measures the proportion of true positive predictions out of all actual positive instances in the data. The recall score is approximately 0.640, meaning that around 64.0% of the actual positive cases were correctly identified by the model.

# %% [markdown]
# ### Model 2: Random Forest Classifier

# %%
# Instantiating the RandomForestClassifier
classifier = RandomForestClassifier(random_state=42)

# Train the classifier on the training data
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the testing data
y_pred = classifier.predict(x_test)

# Evaluate the model using various metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"ROC AUC Score: {roc_auc:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.95
# Precision: 0.92
# Recall: 0.73
# F1 Score: 0.81
# ROC AUC Score: 0.86
# Confusion Matrix:
# [[671   7]
#  [ 31  83]]

# %% [markdown]
# The accuracy score for the Random Forest Classifier model is approximately 0.95, indicating that around 95.0% of the instances in the test set were correctly classified by the model.
#
# The precision score is approximately 0.94, meaning that around 94.0% of the predicted positive cases were correct out of all positive predictions made by the model.
#
# The recall score is approximately 0.70, indicating that around 70.0% of the actual positive cases were correctly identified by the model out of all actual positive instances in the data.
#
# The F1 score is the harmonic mean of precision and recall. It provides a balance between precision and recall. In this case, the F1 score is approximately 0.80.
#
# The ROC AUC (Receiver Operating Characteristic Area Under the Curve) score measures the area under the ROC curve, which represents the model's ability to discriminate between positive and negative classes across different thresholds. The score is approximately 0.84, indicating good discrimination ability.
#
# The confusion matrix provides a tabular summary of the model's predictions versus the actual labels. It shows the number of true negatives, false positives, false negatives, and true positives. In this case, the confusion matrix shows [[664, 5], [34, 78]], indicating 664 true negatives, 5 false positives, 34 false negatives, and 78 true positives.

# %% [markdown]
# ### Model 3: Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
# instantiate gradient boost classifier object
GradientBoostingClassifier = GradientBoostingClassifier(random_state = 42)

# fit the model to the training data:
GradientBoostingClassifier.fit(x_train, y_train)

# prediction
pred =GradientBoostingClassifier.predict(x_test)

# model eveluation
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))
print("Recall:",recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.952020202020202
# Precision: 0.9222222222222223
# Recall: 0.7280701754385965

# %% [markdown]
# The accuracy score for the Gradient Boosting model is approximately 0.950, indicating that around 95% of the instances in the test set were correctly classified by the model.
#
# The precision score is approximately 0.939, meaning that around 93.9% of the predicted positive cases were correct out of all positive predictions made by the model.
#
# The recall score is approximately 0.696, indicating that around 69.6% of the actual positive cases were correctly identified by the model out of all actual positive instances in the data.

# %% [markdown]
# # conclusion

# %% [markdown]
# Based on these metrics, the Random Forest Classifier appears to perform the best among the three models. It has the highest accuracy, precision, recall, F1 score, and ROC AUC score. Therefore, if we prioritize overall performance and balance between precision and recall, we should choose the Random Forest Classifier model for this particular task.
